# %%
import warnings
warnings.filterwarnings('ignore')
import requests
from bs4 import BeautifulSoup
from datetime import datetime as dt

# %%
targetSite = 'https://www.melon.com/chart/index.htm'

# %%
# request = requests.get(targetSite)
# print(request) # <Response [406]> => 헤더 정보 문제로 읽어오지 못함

# %%
# 헤더 정보 문제로 웹 사이트의 데이터를 읽어오지 못할 경우 아래와 같이 헤더 정보를 설정한 후 읽는다.
# 헤더 정보 사이트 
#    => https://developers.whatismybrowser.com/useragents/explore/layout_engine_name/trident/
header = {'User-agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko'}
request = requests.get(targetSite, headers = header)
# print(request)
html = request.text
# print(html)
soup = BeautifulSoup(html, 'html.parser')
# print(soup)

# %%
# 노래 제목 크롤링
titles = soup.findAll('div', {'class': 'ellipsis rank01'})
# print(titles)
# print(len(titles))

for title in titles:
    # print(title.text.strip())
    # print(title.text.split('\n')[1])
    print(title.text.strip().split('\n')[0])
# Out:
# Dynamite
# 힘든 건 사랑이 아니다
# 잠이 오질 않네요
# Lovesick Girls
# 취기를 빌려 (취향저격 그녀 X 산들)
# DON'T TOUCH ME
# 오래된 노래
# 딩가딩가 (Dingga)
# Savage Love (Laxed - Siren Beat) (BTS Remix)
# 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
# 뻔한남자
# When We Disco (Duet with 선미)
# I CAN’T STOP ME
# 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# 가을밤에 든 생각
# 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# 에잇(Prod.&Feat. SUGA of BTS)
# How You Like That
# 눈누난나 (NUNU NANA)
# 어떻게 지내 (Prod. By VAN.C)
# 마리아 (Maria)
# 늦은 밤 너의 집 앞 골목길에서
# Dolphin
# 놓아줘 (with 태연)
# 아로하
# Blueming
# METEOR
# 거짓말이라도 해서 널 보고싶어
# 밤하늘의 별을(2020)
# HAPPENING
# 홀로
# 모든 날, 모든 순간 (Every day, Every Moment)
# 서면역에서
# Dance Monkey
# Downtown Baby
# 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
# Memories
# 사랑은 지날수록 더욱 선명하게 남아
# 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)
# 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
# 다시 여기 바닷가
# 우리 왜 헤어져야 해
# 마음을 드려요
# Bad Boy
# 살짝 설렜어 (Nonstop)
# 2002
# 너도 아는
# 사랑 못해, 남들 쉽게 다 하는 거
# 사랑하게 될 줄 알았어
# AYA
# 처음처럼
# 사실 나는 (Feat.전건호)
# 안녕
# Don't Start Now
# 소확행
# 행복해
# 봄날
# 별을 담은 시 (Ode To The Stars)
# 덤디덤디 (DUMDi DUMDi)
# 이제 나만 믿어요
# Pretty Savage
# 축하해 (Prod. By VAN.C)
# 너를 만나
# 12:45 (Stripped)
# 아무노래
# 도망가
# Love poem
# Paris In The Rain
# 시작
# Maniac
# Ice Cream (with Selena Gomez)
# Summer Hate (Feat. 비)
# Not Shy
# ON
# 가을 타나 봐
# 밤새 (취향저격 그녀 X 카더가든)
# 광장동에서
# 보라빛 밤 (pporappippam)
# 너의 곁에만 맴돌아
# 취했나봐
# 그때 그 아인
# 시든 꽃에 물을 주듯
# 좋은 사람 있으면 소개시켜줘
# 첫 줄
# Psycho
# Into the I-LAND
# 니 이름 불렀나 봐
# bad guy
# Painkiller
# 하루도 그대를 사랑하지 않은 적이 없었다
# RADIO
# Stuck with U
# 사랑하고 싶지 않아 (바른연애 길잡이 X XIA (준수))
# HIP
# 사랑이란 멜로는 없어
# 밤하늘의 저 별처럼
# 나비와 고양이 (feat.백현 (BAEKHYUN))
# 잠이 들어야 (Feat. 헤이즈)
# 반만
# Dancing Cartoon

# %%
# 아티스트 크롤링
artists = soup.findAll('span', {'class': 'checkEllipsis'})
# print(artists)
# print(len(artists))

for artist in artists:
    # print(artist.text.strip())
    # print(artist.text.split('\n')[0])
    print(artist.text.strip().split('\n')[0])
# Out:
# 방탄소년단
# 임창정
# 장범준
# BLACKPINK
# 산들
# 환불원정대
# 스탠딩 에그
# 마마무 (Mamamoo)
# Jawsh 685, Jason Derulo, 방탄소년단
# 규현 (KYUHYUN)
# 이승기
# 박진영
# TWICE (트와이스)
# AKMU (악동뮤지션)
# 잔나비
# 장범준
# 아이유
# BLACKPINK
# 제시 (Jessi)
# 오반
# 화사 (Hwa Sa)
# 노을
# 오마이걸 (OH MY GIRL)
# Crush
# 조정석
# 아이유
# 창모 (CHANGMO)
# 백지영
# 경서
# AKMU (악동뮤지션)
# 이하이
# 폴킴
# 순순희
# Tones And I
# 블루 (BLOO)
# 적재
# Maroon 5
# 전상근
# 마크툽 (MAKTUB)
# 방탄소년단
# 싹쓰리 (유두래곤, 린다G, 비룡)
# 신예영
# 아이유
# 청하, Christopher
# 오마이걸 (OH MY GIRL)
# Anne-Marie
# 폴킴
# 먼데이 키즈 (Monday Kiz)
# 전미도
# 마마무 (Mamamoo)
# 엠씨더맥스 (M.C the MAX)
# 경서예지
# 폴킴
# Dua Lipa
# 임창정
# 송하예
# 방탄소년단
# 마크툽 (MAKTUB), 이라온
# (여자)아이들
# 임영웅
# BLACKPINK
# 오반
# 폴킴
# Etham
# 지코 (ZICO)
# MINO (송민호)
# 아이유
# Lauv
# 가호 (Gaho)
# Conan Gray
# BLACKPINK
# 지코 (ZICO)
# ITZY (있지)
# 방탄소년단
# 바이브
# 카더가든
# 창모 (CHANGMO)
# 선미
# 노을
# 황인욱
# 김필
# HYNN (박혜원)
# 조이 (JOY)
# 신용재 (2F)
# Red Velvet (레드벨벳)
# 아이유
# V.O.S
# Billie Eilish
# Ruel
# 임창정
# 헨리 (HENRY)
# Ariana Grande, Justin Bieber
# 김준수
# 마마무 (Mamamoo)
# 전상근
# 헤이즈 (Heize), 펀치 (Punch)
# 볼빨간사춘기
# 로꼬
# 진민호
# 볼빨간사춘기

# %%
print(dt.now())
for i in range(len(titles)):
    artist = artists[i].text.strip().split('\n')[0]
    title = titles[i].text.strip().split('\n')[0]
    print('{0:3d}위 {1} - {2}'.format(i + 1, artist, title))
# Out:
# 2020-11-19 21:16:19.348838
#   1위 방탄소년단 - Dynamite
#   2위 임창정 - 힘든 건 사랑이 아니다
#   3위 장범준 - 잠이 오질 않네요
#   4위 BLACKPINK - Lovesick Girls
#   5위 산들 - 취기를 빌려 (취향저격 그녀 X 산들)
#   6위 환불원정대 - DON'T TOUCH ME
#   7위 스탠딩 에그 - 오래된 노래
#   8위 마마무 (Mamamoo) - 딩가딩가 (Dingga)
#   9위 Jawsh 685, Jason Derulo, 방탄소년단 - Savage Love (Laxed - Siren Beat) (BTS Remix)
#  10위 규현 (KYUHYUN) - 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
#  11위 이승기 - 뻔한남자
#  12위 박진영 - When We Disco (Duet with 선미)
#  13위 TWICE (트와이스) - I CAN’T STOP ME
#  14위 AKMU (악동뮤지션) - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
#  15위 잔나비 - 가을밤에 든 생각
#  16위 장범준 - 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
#  17위 아이유 - 에잇(Prod.&Feat. SUGA of BTS)
#  18위 BLACKPINK - How You Like That
#  19위 제시 (Jessi) - 눈누난나 (NUNU NANA)
#  20위 오반 - 어떻게 지내 (Prod. By VAN.C)
#  21위 화사 (Hwa Sa) - 마리아 (Maria)
#  22위 노을 - 늦은 밤 너의 집 앞 골목길에서
#  23위 오마이걸 (OH MY GIRL) - Dolphin
#  24위 Crush - 놓아줘 (with 태연)
#  25위 조정석 - 아로하
#  26위 아이유 - Blueming
#  27위 창모 (CHANGMO) - METEOR
#  28위 백지영 - 거짓말이라도 해서 널 보고싶어
#  29위 경서 - 밤하늘의 별을(2020)
#  30위 AKMU (악동뮤지션) - HAPPENING
#  31위 이하이 - 홀로
#  32위 폴킴 - 모든 날, 모든 순간 (Every day, Every Moment)
#  33위 순순희 - 서면역에서
#  34위 Tones And I - Dance Monkey
#  35위 블루 (BLOO) - Downtown Baby
#  36위 적재 - 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
#  37위 Maroon 5 - Memories
#  38위 전상근 - 사랑은 지날수록 더욱 선명하게 남아
#  39위 마크툽 (MAKTUB) - 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)
#  40위 방탄소년단 - 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
#  41위 싹쓰리 (유두래곤, 린다G, 비룡) - 다시 여기 바닷가
#  42위 신예영 - 우리 왜 헤어져야 해
#  43위 아이유 - 마음을 드려요
#  44위 청하, Christopher - Bad Boy
#  45위 오마이걸 (OH MY GIRL) - 살짝 설렜어 (Nonstop)
#  46위 Anne-Marie - 2002
#  47위 폴킴 - 너도 아는
#  48위 먼데이 키즈 (Monday Kiz) - 사랑 못해, 남들 쉽게 다 하는 거
#  49위 전미도 - 사랑하게 될 줄 알았어
#  50위 마마무 (Mamamoo) - AYA
#  51위 엠씨더맥스 (M.C the MAX) - 처음처럼
#  52위 경서예지 - 사실 나는 (Feat.전건호)
#  53위 폴킴 - 안녕
#  54위 Dua Lipa - Don't Start Now
#  55위 임창정 - 소확행
#  56위 송하예 - 행복해
#  57위 방탄소년단 - 봄날
#  58위 마크툽 (MAKTUB), 이라온 - 별을 담은 시 (Ode To The Stars)
#  59위 (여자)아이들 - 덤디덤디 (DUMDi DUMDi)
#  60위 임영웅 - 이제 나만 믿어요
#  61위 BLACKPINK - Pretty Savage
#  62위 오반 - 축하해 (Prod. By VAN.C)
#  63위 폴킴 - 너를 만나
#  64위 Etham - 12:45 (Stripped)
#  65위 지코 (ZICO) - 아무노래
#  66위 MINO (송민호) - 도망가
#  67위 아이유 - Love poem
#  68위 Lauv - Paris In The Rain
#  69위 가호 (Gaho) - 시작
#  70위 Conan Gray - Maniac
#  71위 BLACKPINK - Ice Cream (with Selena Gomez)
#  72위 지코 (ZICO) - Summer Hate (Feat. 비)
#  73위 ITZY (있지) - Not Shy
#  74위 방탄소년단 - ON
#  75위 바이브 - 가을 타나 봐
#  76위 카더가든 - 밤새 (취향저격 그녀 X 카더가든)
#  77위 창모 (CHANGMO) - 광장동에서
#  78위 선미 - 보라빛 밤 (pporappippam)
#  79위 노을 - 너의 곁에만 맴돌아
#  80위 황인욱 - 취했나봐
#  81위 김필 - 그때 그 아인
#  82위 HYNN (박혜원) - 시든 꽃에 물을 주듯
#  83위 조이 (JOY) - 좋은 사람 있으면 소개시켜줘
#  84위 신용재 (2F) - 첫 줄
#  85위 Red Velvet (레드벨벳) - Psycho
#  86위 아이유 - Into the I-LAND
#  87위 V.O.S - 니 이름 불렀나 봐
#  88위 Billie Eilish - bad guy
#  89위 Ruel - Painkiller
#  90위 임창정 - 하루도 그대를 사랑하지 않은 적이 없었다
#  91위 헨리 (HENRY) - RADIO
#  92위 Ariana Grande, Justin Bieber - Stuck with U
#  93위 김준수 - 사랑하고 싶지 않아 (바른연애 길잡이 X XIA (준수))
#  94위 마마무 (Mamamoo) - HIP
#  95위 전상근 - 사랑이란 멜로는 없어
#  96위 헤이즈 (Heize), 펀치 (Punch) - 밤하늘의 저 별처럼
#  97위 볼빨간사춘기 - 나비와 고양이 (feat.백현 (BAEKHYUN))
#  98위 로꼬 - 잠이 들어야 (Feat. 헤이즈)
#  99위 진민호 - 반만
# 100위 볼빨간사춘기 - Dancing Cartoon

# %%
file = open('melonTOP100.txt', 'w')
file.write('{} 현재 Melon 뮤직 실시간 TOP 100\n'.format(dt.now()))
for i in range(100):
    artist = artists[i].text.strip().split('\n')[0]
    title = titles[i].text.strip().split('\n')[0]
    data = '{0:3d}위 {1} - {2}'.format(i + 1, artist, title)
    file.write(data + '\n')
file.close()
print('melonTOP100.txt 파일로 쓰기 완료')
# Out:
# melonTOP100.txt 파일로 쓰기 완료

# %%
try:
    file = open('melonTOP100.txt', 'r')
    lines = file.readlines()
    for line in lines:
        print(line.strip())
    file.close()
    print('melonTOP100.txt 파일에서 읽기 완료')
except:
    print('디스크에 읽어올 파일이 없습니다.')
# Out:
# 2020-11-19 21:17:39.821705 현재 Melon 뮤직 실시간 TOP 100
# 1위 방탄소년단 - Dynamite
# 2위 임창정 - 힘든 건 사랑이 아니다
# 3위 장범준 - 잠이 오질 않네요
# 4위 BLACKPINK - Lovesick Girls
# 5위 산들 - 취기를 빌려 (취향저격 그녀 X 산들)
# 6위 환불원정대 - DON'T TOUCH ME
# 7위 스탠딩 에그 - 오래된 노래
# 8위 마마무 (Mamamoo) - 딩가딩가 (Dingga)
# 9위 Jawsh 685, Jason Derulo, 방탄소년단 - Savage Love (Laxed - Siren Beat) (BTS Remix)
# 10위 규현 (KYUHYUN) - 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
# 11위 이승기 - 뻔한남자
# 12위 박진영 - When We Disco (Duet with 선미)
# 13위 TWICE (트와이스) - I CAN’T STOP ME
# 14위 AKMU (악동뮤지션) - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# 15위 잔나비 - 가을밤에 든 생각
# 16위 장범준 - 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# 17위 아이유 - 에잇(Prod.&Feat. SUGA of BTS)
# 18위 BLACKPINK - How You Like That
# 19위 제시 (Jessi) - 눈누난나 (NUNU NANA)
# 20위 오반 - 어떻게 지내 (Prod. By VAN.C)
# 21위 화사 (Hwa Sa) - 마리아 (Maria)
# 22위 노을 - 늦은 밤 너의 집 앞 골목길에서
# 23위 오마이걸 (OH MY GIRL) - Dolphin
# 24위 Crush - 놓아줘 (with 태연)
# 25위 조정석 - 아로하
# 26위 아이유 - Blueming
# 27위 창모 (CHANGMO) - METEOR
# 28위 백지영 - 거짓말이라도 해서 널 보고싶어
# 29위 경서 - 밤하늘의 별을(2020)
# 30위 AKMU (악동뮤지션) - HAPPENING
# 31위 이하이 - 홀로
# 32위 폴킴 - 모든 날, 모든 순간 (Every day, Every Moment)
# 33위 순순희 - 서면역에서
# 34위 Tones And I - Dance Monkey
# 35위 블루 (BLOO) - Downtown Baby
# 36위 적재 - 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
# 37위 Maroon 5 - Memories
# 38위 전상근 - 사랑은 지날수록 더욱 선명하게 남아
# 39위 마크툽 (MAKTUB) - 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)
# 40위 방탄소년단 - 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
# 41위 싹쓰리 (유두래곤, 린다G, 비룡) - 다시 여기 바닷가
# 42위 신예영 - 우리 왜 헤어져야 해
# 43위 아이유 - 마음을 드려요
# 44위 청하, Christopher - Bad Boy
# 45위 오마이걸 (OH MY GIRL) - 살짝 설렜어 (Nonstop)
# 46위 Anne-Marie - 2002
# 47위 폴킴 - 너도 아는
# 48위 먼데이 키즈 (Monday Kiz) - 사랑 못해, 남들 쉽게 다 하는 거
# 49위 전미도 - 사랑하게 될 줄 알았어
# 50위 마마무 (Mamamoo) - AYA
# 51위 엠씨더맥스 (M.C the MAX) - 처음처럼
# 52위 경서예지 - 사실 나는 (Feat.전건호)
# 53위 폴킴 - 안녕
# 54위 Dua Lipa - Don't Start Now
# 55위 임창정 - 소확행
# 56위 송하예 - 행복해
# 57위 방탄소년단 - 봄날
# 58위 마크툽 (MAKTUB), 이라온 - 별을 담은 시 (Ode To The Stars)
# 59위 (여자)아이들 - 덤디덤디 (DUMDi DUMDi)
# 60위 임영웅 - 이제 나만 믿어요
# 61위 BLACKPINK - Pretty Savage
# 62위 오반 - 축하해 (Prod. By VAN.C)
# 63위 폴킴 - 너를 만나
# 64위 Etham - 12:45 (Stripped)
# 65위 지코 (ZICO) - 아무노래
# 66위 MINO (송민호) - 도망가
# 67위 아이유 - Love poem
# 68위 Lauv - Paris In The Rain
# 69위 가호 (Gaho) - 시작
# 70위 Conan Gray - Maniac
# 71위 BLACKPINK - Ice Cream (with Selena Gomez)
# 72위 지코 (ZICO) - Summer Hate (Feat. 비)
# 73위 ITZY (있지) - Not Shy
# 74위 방탄소년단 - ON
# 75위 바이브 - 가을 타나 봐
# 76위 카더가든 - 밤새 (취향저격 그녀 X 카더가든)
# 77위 창모 (CHANGMO) - 광장동에서
# 78위 선미 - 보라빛 밤 (pporappippam)
# 79위 노을 - 너의 곁에만 맴돌아
# 80위 황인욱 - 취했나봐
# 81위 김필 - 그때 그 아인
# 82위 HYNN (박혜원) - 시든 꽃에 물을 주듯
# 83위 조이 (JOY) - 좋은 사람 있으면 소개시켜줘
# 84위 신용재 (2F) - 첫 줄
# 85위 Red Velvet (레드벨벳) - Psycho
# 86위 아이유 - Into the I-LAND
# 87위 V.O.S - 니 이름 불렀나 봐
# 88위 Billie Eilish - bad guy
# 89위 Ruel - Painkiller
# 90위 임창정 - 하루도 그대를 사랑하지 않은 적이 없었다
# 91위 헨리 (HENRY) - RADIO
# 92위 Ariana Grande, Justin Bieber - Stuck with U
# 93위 김준수 - 사랑하고 싶지 않아 (바른연애 길잡이 X XIA (준수))
# 94위 마마무 (Mamamoo) - HIP
# 95위 전상근 - 사랑이란 멜로는 없어
# 96위 헤이즈 (Heize), 펀치 (Punch) - 밤하늘의 저 별처럼
# 97위 볼빨간사춘기 - 나비와 고양이 (feat.백현 (BAEKHYUN))
# 98위 로꼬 - 잠이 들어야 (Feat. 헤이즈)
# 99위 진민호 - 반만
# 100위 볼빨간사춘기 - Dancing Cartoon
# melonTOP100.txt 파일에서 읽기 완료

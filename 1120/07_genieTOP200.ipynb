# %%
import warnings
warnings.filterwarnings('ignore')
import requests
from bs4 import BeautifulSoup
from datetime import datetime as dt
import time
header = {'User-agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko'}

# %%
# 타겟 사이트 주소 만들기
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20201119&hh=21&rtm=Y&pg=1 =>  1  ~  50
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20201119&hh=21&rtm=Y&pg=2 =>  51 ~ 100
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20201119&hh=21&rtm=Y&pg=3 => 101 ~ 150
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20201119&hh=21&rtm=Y&pg=4 => 151 ~ 200
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20201119&hh=21&rtm=Y&pg=' # 변경되지 않는 주소
for i in range(1, 5):
    print('{}{}'.format(url, i))
# Out:
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20201119&hh=21&rtm=Y&pg=1
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20201119&hh=21&rtm=Y&pg=2
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20201119&hh=21&rtm=Y&pg=3
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20201119&hh=21&rtm=Y&pg=4

# %%
# 노래 제목 크롤링
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20201119&hh=21&rtm=Y&pg='
for i in range(1, 2):
    targetSite = '{}{}'.format(url, i)
    # print(targetSite)
    request = requests.get(targetSite, headers = header)
    # print(request)
    html = request.text
    # print(html)
    soup = BeautifulSoup(html, 'html.parser')
    # print(soup)
    
    titles = soup.findAll('a', {'class': 'title ellipsis'})
    # print(titles)
    # print(len(titles))

    for title in titles:
        # print(title.text.strip())
        # print(title.text.split('\n')[-1])
        print(title.text.strip().split('\n')[0])
# Out:
# 밤하늘의 별을 (2020)
# 뻔한남자
# 잠이 오질 않네요
# Dynamite
# HAPPENING
# 가을밤에 든 생각
# 힘든 건 사랑이 아니다
# Lovesick Girls
# 딩가딩가 (Dingga)
# I CAN'T STOP ME
# 이제 나만 믿어요
# 취기를 빌려 (취향저격 그녀 X 산들)
# DON'T TOUCH ME
# Savage Love (Laxed - Siren Beat) (BTS Remix)
# 너도 아는
# HERO
# 오래된 노래
# AYA
# 오래된 노래
# Midnight
# MAGO
# 어느 60대 노부부이야기
# Dancing Cartoon
# Bad Boy
# 만개 (Prod. 신지후)
# 바램
# 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
# 밤하늘의 저 별처럼
# 광장동에서
# 보라빛 엽서
# 나보다 더 사랑해요
# 살았소
# 우산이 없어요
# When We Disco (Duet With 선미)
# 에잇 (Prod. & Feat. SUGA of BTS)
# 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
# 이제 나만 믿어요 (Piano by 조영수)
# 도망가
# 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# 어느날 문득
# 미워요
# How You Like That
# 계단말고 엘리베이터
# 사실 나는 (Feat. 전건호)
# 백화 (白花) (Narration. 손숙)
# 퇴근길
# 나만의 길 (My Way)
# Blueming
# 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# Show Your Love

# %%
# 아티스트 크롤링
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20201119&hh=21&rtm=Y&pg='
for i in range(1, 2):
    targetSite = '{}{}'.format(url, i)
    request = requests.get(targetSite, headers = header)
    html = request.text
    soup = BeautifulSoup(html, 'html.parser')
    
    artists = soup.findAll('a', {'class': 'artist ellipsis'})
    # print(artists)
    # print(len(artists)) # 55

    for artist in artists[5:]:
        # print(artist.text.strip())
        # print(artist.text.split('\n')[0])
        print(artist.text.strip().split('\n')[0])
# Out:
# 경서
# 이승기
# 장범준
# 방탄소년단
# AKMU (악동뮤지션)
# 잔나비
# 임창정
# BLACKPINK
# 마마무(Mamamoo)
# TWICE (트와이스)
# 임영웅
# 산들
# 환불원정대
# Jawsh 685 & Jason Derulo & 방탄소년단
# 폴킴
# 임영웅
# 임영웅
# 마마무(Mamamoo)
# Standing Egg (스탠딩 에그)
# 박지훈
# 여자친구 (GFRIEND)
# 임영웅
# 볼빨간사춘기
# 청하 & Christopher
# 김호중
# 임영웅
# 규현 (KYUHYUN)
# 헤이즈 (Heize) & 펀치 (Punch)
# 창모 (CHANGMO)
# 임영웅
# 김호중
# 김호중
# 김호중
# 박진영
# 아이유 (IU)
# 적재
# 임영웅
# MINO (송민호)
# 장범준
# 임영웅
# 임영웅
# BLACKPINK
# 임영웅
# 경서예지
# 김호중
# 김호중
# 김호중
# 아이유 (IU)
# AKMU (악동뮤지션)
# 비투비 포유

# %%
genies = []
for i in range(1, 5):
    targetSite = '{}{}'.format(url, i)
    request = requests.get(targetSite, headers = header)
    time.sleep(1)
    html = request.text
    soup = BeautifulSoup(html, 'html.parser')
    titles = soup.findAll('a', {'class': 'title ellipsis'})
    artists = soup.findAll('a', {'class': 'artist ellipsis'})
    for i in range(len(titles)):
        genies.append([
            titles[i].text.strip().split('\n')[0], \
            artists[i + 5].text.strip().split('\n')[0]\
        ])

# %%
print(dt.now())
for i in range(len(genies)):
    print('{0:3d}위 {1} - {2}'.format(i + 1, genies[i][0], genies[i][1]))
# Out:
# 2020-11-20 19:16:27.258754
#   1위 밤하늘의 별을 (2020) - 경서
#   2위 뻔한남자 - 이승기
#   3위 잠이 오질 않네요 - 장범준
#   4위 Dynamite - 방탄소년단
#   5위 HAPPENING - AKMU (악동뮤지션)
#   6위 가을밤에 든 생각 - 잔나비
#   7위 힘든 건 사랑이 아니다 - 임창정
#   8위 Lovesick Girls - BLACKPINK
#   9위 딩가딩가 (Dingga) - 마마무(Mamamoo)
#  10위 I CAN'T STOP ME - TWICE (트와이스)
#  11위 이제 나만 믿어요 - 임영웅
#  12위 취기를 빌려 (취향저격 그녀 X 산들) - 산들
#  13위 DON'T TOUCH ME - 환불원정대
#  14위 Savage Love (Laxed - Siren Beat) (BTS Remix) - Jawsh 685 & Jason Derulo & 방탄소년단
#  15위 너도 아는 - 폴킴
#  16위 HERO - 임영웅
#  17위 오래된 노래 - 임영웅
#  18위 AYA - 마마무(Mamamoo)
#  19위 오래된 노래 - Standing Egg (스탠딩 에그)
#  20위 Midnight - 박지훈
#  21위 MAGO - 여자친구 (GFRIEND)
#  22위 어느 60대 노부부이야기 - 임영웅
#  23위 Dancing Cartoon - 볼빨간사춘기
#  24위 Bad Boy - 청하 & Christopher
#  25위 만개 (Prod. 신지후) - 김호중
#  26위 바램 - 임영웅
#  27위 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현) - 규현 (KYUHYUN)
#  28위 밤하늘의 저 별처럼 - 헤이즈 (Heize) & 펀치 (Punch)
#  29위 광장동에서 - 창모 (CHANGMO)
#  30위 보라빛 엽서 - 임영웅
#  31위 나보다 더 사랑해요 - 김호중
#  32위 살았소 - 김호중
#  33위 우산이 없어요 - 김호중
#  34위 When We Disco (Duet With 선미) - 박진영
#  35위 에잇 (Prod. & Feat. SUGA of BTS) - 아이유 (IU)
#  36위 나랑 같이 걸을래 (바른연애 길잡이 X 적재) - 적재
#  37위 이제 나만 믿어요 (Piano by 조영수) - 임영웅
#  38위 도망가 - MINO (송민호)
#  39위 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야 - 장범준
#  40위 어느날 문득 - 임영웅
#  41위 미워요 - 임영웅
#  42위 How You Like That - BLACKPINK
#  43위 계단말고 엘리베이터 - 임영웅
#  44위 사실 나는 (Feat. 전건호) - 경서예지
#  45위 백화 (白花) (Narration. 손숙) - 김호중
#  46위 퇴근길 - 김호중
#  47위 나만의 길 (My Way) - 김호중
#  48위 Blueming - 아이유 (IU)
#  49위 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지 - AKMU (악동뮤지션)
#  50위 Show Your Love - 비투비 포유
#  51위 마리아 (Maria) - 화사 (Hwa Sa)
#  52위 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey) - 방탄소년단
#  53위 애인이 되어줄게요 (Prod. by 알고보니 & 혼수상태) - 김호중
#  54위 METEOR - 창모 (CHANGMO)
#  55위 고맙소 (Orchestra Ver.) - 김호중
#  56위 Dolphin - 오마이걸 (OH MY GIRL)
#  57위 눈누난나 (NUNU NANA) - 제시
#  58위 Black Mamba - aespa
#  59위 Stay With Me - 유아 (오마이걸)
#  60위 모든 날, 모든 순간 (Every day, Every Moment) - 폴킴
#  61위 늦은 밤 너의 집 앞 골목길에서 - 노을
#  62위 놓아줘 (With 태연) - Crush
#  63위 사랑 못해, 남들 쉽게 다 하는 거 - 먼데이 키즈 (Monday Kiz)
#  64위 Downtown Baby - 블루 (BLOO)
#  65위 2002 - Anne-Marie
#  66위 아로하 - 조정석
#  67위 Dance Monkey - Tones And I
#  68위 어떻게 지내 (Prod. by VAN.C) - 오반
#  69위 소확행 - 임창정
#  70위 Memories - Maroon 5
#  71위 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온) - 마크툽 (Maktub)
#  72위 살짝 설렜어 (Nonstop) - 오마이걸 (OH MY GIRL)
#  73위 ON - 방탄소년단
#  74위 홀로 - 이하이
#  75위 잠이 들어야 (Feat. 헤이즈) - 로꼬
#  76위 거짓말이라도 해서 널 보고싶어 - 백지영
#  77위 행복해 - 송하예
#  78위 행복하니 - 케이시 (Kassy)
#  79위 노래방에서 - 장범준
#  80위 주저하는 연인들을 위해 - 잔나비
#  81위 봄날 - 방탄소년단
#  82위 아무노래 - 지코 (ZICO)
#  83위 다시 여기 바닷가 - 싹쓰리 (유두래곤 & 린다G & 비룡)
#  84위 Don't Start Now - Dua Lipa
#  85위 12 : 45 (Stripped) - etham
#  86위 Pretty Savage - BLACKPINK
#  87위 서면역에서 - 순순희
#  88위 나의 밤 (Feat. 전상근) - 에이치코드 (H:CODE)
#  89위 우리 왜 헤어져야 해 - 신예영
#  90위 사랑하고 싶지 않아 (바른연애 길잡이 X XIA (준수)) - XIA (준수)
#  91위 Ice Cream (With Selena Gomez) - BLACKPINK
#  92위 Maniac - Conan Gray
#  93위 마음을 드려요 - 아이유 (IU)
#  94위 Not Shy - ITZY (있지)
#  95위 안녕 - 폴킴
#  96위 축하해 (Prod. by VAN.C) - 오반
#  97위 너의 번호를 누르고 (Prod. by 영화처럼) - #안녕
#  98위 사랑하게 될 줄 알았어 - 전미도
#  99위 HIP - 마마무(Mamamoo)
# 100위 처음처럼 - 엠씨더맥스 (M.C the MAX)
# 101위 Paris In The Rain - Lauv
# 102위 사랑은 지날수록 더욱 선명하게 남아 - 전상근
# 160위 보라빛 밤 (pporappippam) - 선미
# 161위 반만 - 진민호
# 162위 내 눈물 모아 - 휘인 (Whee In)
# 163위 니가 없다면 - 김나영
# 164위 듣고 싶던 말 - 허각
# 165위 To Die For - Sam Smith
# 166위 Make A Wish (Birthday Song) - NCT U
# 167위 취했나봐 - 황인욱
# 168위 화려하지 않은 고백 - 규현 (KYUHYUN)
# 169위 다시 만날까 봐 - V.O.S
# 170위 삐삐 - 아이유 (IU)
# 171위 나비와 고양이 (Feat. 백현 (BAEKHYUN)) - 볼빨간사춘기
# 172위 cheap sunglasses - John K
# 173위 Black Swan - 방탄소년단
# 174위 The Ocean (Feat. Shy Martin) (Radio Edit) - Mike Perry
# 175위 니 소식 - 송하예
# 176위 너의 모든 순간 - 성시경
# 177위 아직 너의 시간에 살아 - 이수현
# 178위 Heaven - 태민 (TAEMIN)
# 179위 니 이름 불렀나 봐 - V.O.S
# 180위 신기루 - 비투비 포유
# 181위 그대로예요 - 비투비 포유
# 182위 LINDA (Feat. 윤미래) - 린다G
# 183위 Believer - Imagine Dragons
# 184위 Santa Tell Me - Ariana Grande
# 185위 그 여름을 틀어줘 - 싹쓰리 (유두래곤 & 린다G & 비룡)
# 186위 별 보러 가자 - 적재
# 187위 친구 - 방탄소년단
# 188위 다시 난, 여기 - 백예린
# 189위 Faded - Alan Walker
# 190위 알았다면 - 길구봉구
# 191위 어느 날 우리 - 김필
# 192위 Attention - Charlie Puth
# 193위 Be Your Enemy (Feat. WENDY of Red Velvet) - 태민 (TAEMIN)
# 194위 돌덩이 - 하현우 (국카스텐)
# 195위 Bull's Eye - 비투비 포유
# 196위 신난다 (Feat. 마마무) - 비룡
# 197위 너에게 못했던 내 마지막 말은 - 다비치
# 198위 WANNABE - ITZY (있지)
# 199위 Tension - 비투비 포유
# 200위 Mood (Feat. Iann Dior) - 24KGoldn

# %%
file = open('genieTOP200.txt', 'w')
file.write('{} 현재 Genie 뮤직 실시간 TOP 100\n'.format(str(dt.now())))
for i in range(200):
    data = '{0:3d}위 {1} - {2}'.format(i + 1, genies[i][0], genies[i][1])
    file.write(data + '\n')
file.close()
print('genieTOP200.txt 파일로 쓰기 완료')
# Out:
# genieTOP200.txt 파일로 쓰기 완료

# %%
try:
    file = open('genieTOP200.txt', 'r')
    lines = file.readlines()
    for line in lines:
        print(line.strip())
    file.close()
    print('genieTOP200.txt 파일에서 읽기 완료')
except:
    print('디스크에 읽어올 파일이 없습니다.')
# Out:
# 2020-11-20 19:20:33.383073 현재 Genie 뮤직 실시간 TOP 100
# 1위 밤하늘의 별을 (2020) - 경서
# 2위 뻔한남자 - 이승기
# 3위 잠이 오질 않네요 - 장범준
# 4위 Dynamite - 방탄소년단
# 5위 HAPPENING - AKMU (악동뮤지션)
# 6위 가을밤에 든 생각 - 잔나비
# 7위 힘든 건 사랑이 아니다 - 임창정
# 8위 Lovesick Girls - BLACKPINK
# 9위 딩가딩가 (Dingga) - 마마무(Mamamoo)
# 10위 I CAN'T STOP ME - TWICE (트와이스)
# 11위 이제 나만 믿어요 - 임영웅
# 12위 취기를 빌려 (취향저격 그녀 X 산들) - 산들
오늘도 빛나는 너에게 (To You My Light) (Feat.이라온) - 마크툽 (Maktub)
# 72위 살짝 설렜어 (Nonstop) - 오마이걸 (OH MY GIRL)
# 73위 ON - 방탄소년단
# 74위 홀로 - 이하이
# 75위 잠이 들어야 (Feat. 헤이즈) - 로꼬
# 76위 거짓말이라도 해서 널 보고싶어 - 백지영
# 77위 행복해 - 송하예
# 78위 행복하니 - 케이시 (Kassy)
# 79위 노래방에서 - 장범준
# 80위 주저하는 연인들을 위해 - 잔나비
# 81위 봄날 - 방탄소년단
# 82위 아무노래 - 지코 (ZICO)
# 83위 다시 여기 바닷가 - 싹쓰리 (유두래곤 & 린다G & 비룡)
# 84위 Don't Start Now - Dua Lipa
# 85위 12 : 45 (Stripped) - etham
# 86위 Pretty Savage - BLACKPINK
# 87위 서면역에서 - 순순희
# 88위 나의 밤 (Feat. 전상근) - 에이치코드 (H:CODE)
# 89위 우리 왜 헤어져야 해 - 신예영
# 90위 사랑하고 싶지 않아 (바른연애 길잡이 X XIA (준수)) - XIA (준수)
# 91위 Ice Cream (With Selena Gomez) - BLACKPINK
# 92위 Maniac - Conan Gray
# 93위 마음을 드려요 - 아이유 (IU)
# 94위 Not Shy - ITZY (있지)
# 95위 안녕 - 폴킴
# 96위 축하해 (Prod. by VAN.C) - 오반
# 97위 너의 번호를 누르고 (Prod. by 영화처럼) - #안녕
# 98위 사랑하게 될 줄 알았어 - 전미도
# 99위 HIP - 마마무(Mamamoo)
# 100위 처음처럼 - 엠씨더맥스 (M.C the MAX)
# 101위 Paris In The Rain - Lauv
# 102위 사랑은 지날수록 더욱 선명하게 남아 - 전상근
# 103위 밤편지 - 아이유 (IU)
# 104위 Painkiller - Ruel
# 105위 이데아 (IDEA:理想) - 태민 (TAEMIN)
# 106위 과거 현재 미래 (Then, Now and Forever) - CNBLUE (씨엔블루)
# 107위 비 - 폴킴
# 108위 그때가 좋았어 - 케이시 (Kassy)
# 109위 사라진 모든 것들에게 (With ELLE KOREA) - 코드 쿤스트 (CODE KUNST) & 최정훈 (잔나비) & 사이먼 도미닉
# 110위 bad guy - Billie Eilish
# 111위 시작 - 가호 (Gaho)
# 112위 너를 만나 - 폴킴
# 113위 사랑에 연습이 있었다면 (Prod. by 2soo) - 임재현
# 114위 사랑이 식었다고 말해도 돼 - 먼데이 키즈 (Monday Kiz)
# 115위 Bad - Christopher
# 116위 On My Way - Alan Walker & Sabrina Carpenter & Farruko
# 117위 기억해줘요 내 모든 날과 그때를 - 거미 (Gummy)
# 118위 ALIEN - 이수현
# 119위 Love poem - 아이유 (IU)
# 120위 RADIO - 헨리 (HENRY)
# 121위 덤디덤디 (DUMDi DUMDi) - (여자)아이들
# 122위 아틀란티스 소녀 (Atlantis Princess) - 볼빨간사춘기
# 123위 Square (2017) - 백예린
# 124위 All Falls Down (Feat. Noah Cyrus & Digital Farm Animals) - Alan Walker
# 125위 조금 취했어 (Prod. by 2soo) - 임재현
# 126위 시든 꽃에 물을 주듯 - HYNN (박혜원)
# 127위 Bet You Wanna (Feat. Cardi B) - BLACKPINK
# 128위 Senorita - Camila Cabello & Shawn Mendes
# 129위 좋은 사람 있으면 소개시켜줘 - 조이 (JOY)
# 130위 Psycho - Red Velvet (레드벨벳)
# 131위 Into the I-LAND - 아이유 (IU)
# 132위 Comethru - Jeremy Zucker
# 133위 HOME;RUN - 세븐틴 (Seventeen)
# 134위 사랑이란 멜로는 없어 - 전상근
# 135위 그대라는 시 - 태연 (TAEYEON)
